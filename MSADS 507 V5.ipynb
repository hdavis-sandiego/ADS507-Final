# %% [markdown]
# # MSADS 507 M4

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as no
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')


userName = 'root'
userPass = 'yb%Q8!ec'

# %% [markdown]
# ## Creating SQL DB Connection

# %%
conn=mysql.connect(host='localhost',port=int(3306),user='root',passwd='$$AfusA18800!!',db='gravity_books')

# %%
tableNames = pd.read_sql("""SHOW TABLES""", conn) 
tableNames
# Out:
#    Tables_in_gravity_books
# 0                  address
# 1           address_status
# 2                   author
# 3                     book
# 4              book_author
# 5            book_language
# 6                  country
# 7               cust_order
# 8                 customer
# 9         customer_address
# 10                  income
# 11           order_history
# 12              order_line
# 13            order_status
# 14              population
# 15               publisher
# 16         shipping_method

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# 1. Period: the transaction between ** to **

#latest order date:
a = pd.read_sql_query("""

SELECT order_date 
FROM cust_order
ORDER BY order_date DESC 
LIMIT 1

""" , con = conn) 
a
# Out:
#            order_date
# 0 2023-01-29 08:36:41

# %%
# earliest order date:

b = pd.read_sql_query("""

SELECT order_date 
FROM cust_order 
ORDER BY order_date
LIMIT 1

""" , con = conn) 
b
# Out:
#            order_date
# 0 2020-01-30 20:50:23

# %%
# order counts in the first year:

c = pd.read_sql_query("""

SELECT COUNT(*)
FROM cust_order
WHERE order_date BETWEEN '2020-02-06' AND '2021-02-05'

""" , con = conn) 
c
# Out:
#    COUNT(*)
# 0      2541

# %%
# order counts in the second year:

d = pd.read_sql_query("""

SELECT COUNT(*)
FROM cust_order
WHERE order_date BETWEEN '2021-02-06' AND '2022-02-05'

""" , con = conn) 
d
# Out:
#    COUNT(*)
# 0      2548

# %%
# order counts in the last year:

d = pd.read_sql_query("""

SELECT COUNT(*)
FROM cust_order
WHERE order_date BETWEEN '2022-02-06' AND '2023-02-05'

""" , con = conn) 
d
# Out:
#    COUNT(*)
# 0      2412

# %%
# plot of order counts
year = ['Year 1', 'Year 2', 'Year 3']
values = [2541, 2548, 2412]

plt.bar(year, values)
plt.title('Count of Orders per Year')
plt.ylabel('Count')
plt.xlabel('Year')
plt.show()

# %%
# 2. How many orders and books are sold in total?

e = pd.read_sql_query("""

SELECT COUNT(order_id), COUNT(book_id) books_sold
FROM order_line;

""" , con = conn) 
e
# Out:
#    COUNT(order_id)  books_sold
# 0            15400       15400

# %%
# 3. How many customer numbers are in the data?

f = pd.read_sql_query("""

SELECT COUNT(DISTINCT(customer_id)) 
FROM cust_order;

""" , con = conn) 
f
# Out:
#    COUNT(DISTINCT(customer_id))
# 0                          1706

# %%
# 4. Which customer placed the most orders?

g = pd.read_sql_query("""

SELECT c.customer_id, c.first_name, c.last_name, COUNT(*) 
FROM customer c
LEFT JOIN cust_order co
ON c.customer_id = co.customer_id
GROUP BY c.customer_id
ORDER BY COUNT(DISTINCT( co.order_id)) DESC LIMIT 1;

""" , con = conn) 
g
# Out:
#    customer_id first_name last_name  COUNT(*)
# 0         1830     Noella   Ruddoch        21

# %%
# 5. What shipping method is most preferred, and what percentage of total

h = pd.read_sql_query("""

SELECT sm.method_name, COUNT(*),COUNT(*) * 100.0 / SUM(COUNT(*)) OVER() AS 'Percent of total'
FROM shipping_method sm
RIGHT JOIN cust_order co
ON sm.method_id = co.shipping_method_id
GROUP BY sm.method_name
ORDER BY COUNT(*) DESC;

""" , con = conn) 
h
# Out:
#      method_name  COUNT(*)  Percent of total
# 0       Standard      1967          26.05298
# 1  International      1939          25.68212
# 2       Priority      1822          24.13245
# 3        Express      1822          24.13245

# %%
# plot of most preferred shipping method
plt.bar(h['method_name'], h['COUNT(*)'])
plt.title('Bar Chart of Preferred Shipping Method')
plt.ylabel('Count')
plt.xlabel('Shipping Method')
plt.show()

# %%
# 6. author who published the most books:

i = pd.read_sql_query("""

SELECT a.author_id, a.author_name, COUNT(DISTINCT(b.book_id)) AS 'Books Published'
FROM author a
INNER JOIN book_author ba
ON a.author_id = ba.author_id
INNER JOIN book b
ON ba.book_id = b.book_id 
GROUP BY a.author_id
ORDER BY COUNT(DISTINCT(b.book_id)) DESC
LIMIT 1;

""" , con = conn) 
i
# Out:
#    author_id   author_name  Books Published
# 0       8222  Stephen King               70

# %%
# 7. best-selling author

j = pd.read_sql_query("""

SELECT a.author_id, a.author_name, COUNT(ol.order_id) AS Num_Sold 
FROM author a
INNER JOIN book_author ba
ON a.author_id = ba.author_id
INNER JOIN book b
ON ba.book_id= b.book_id
INNER JOIN order_line ol
ON b.book_id = ol.book_id
GROUP BY a.author_id
ORDER BY COUNT(ol.order_id) DESC 
LIMIT 1;

""" , con = conn) 
j
# Out:
#    author_id   author_name  Num_Sold
# 0       8222  Stephen King        88

# %%
# 8. best-selling book
# books sold total

k = pd.read_sql_query("""

SELECT COUNT(book_id)
FROM order_line;

""" , con = conn) 
k
# Out:
#    COUNT(book_id)
# 0           15400

# %%
# DISTINCT books sold in total

l = pd.read_sql_query("""

SELECT COUNT(DISTINCT(book_id))
FROM order_line;

""" , con = conn) 
l
# Out:
#    COUNT(DISTINCT(book_id))
# 0                      8352

# %%
# best-selling book

m = pd.read_sql_query("""

SELECT b.book_id, b.title, COUNT(*)
FROM book b
RIGHT JOIN order_line ol
ON b.book_id = ol.book_id
GROUP BY b.book_id
ORDER BY COUNT(*) DESC
LIMIT 10;

""" , con = conn) 
m
# Out:
#    book_id                                              title  COUNT(*)
# 0     9669                                  A Christmas Carol         8
# 1     1090  Difficult Conversations: How to Discuss What M...         7
# 2     7408                              The Origin of Species         7
# 3     7707                               Robert Frost: A Life         7
# 4     4465                The Black Dahlia (L.A. Quartet  #1)         7
# 5     4745                                               Sula         7
# 6     2634                                     Girl Meets Ape         6
# 7       90      And to Think That I Saw It on Mulberry Street         6
# 8     3178                                      The Diagnosis         6
# 9     3043                             The Brothers Karamazov         6

# %%
# plot of best selling book
plt.bar(m['title'], m['COUNT(*)'])
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.title('Bar Chart of Best Selling Books')
plt.ylabel('Count')
plt.xlabel('Book Title')
plt.show()

# %%
# 9. Which book makes the most profit: 

n = pd.read_sql_query("""

SELECT ol.book_id, b.title, a.author_name, SUM(ol.price) 
FROM order_line ol
LEFT JOIN book b
ON ol.book_id = b.book_id
LEFT JOIN book_author ba
ON b.book_id = ba.author_id
LEFT JOIN author a
ON ba.author_id = a.author_id
GROUP BY ol.book_id 
ORDER BY SUM(ol.price) DESC 
LIMIT 1;

""" , con = conn) 
n
# Out:
#    book_id                                              title  \
# 0     3760  Sauron Defeated: The History of The Lord of th...
#
#        author_name  SUM(ol.price)
# 0  James Patterson        1160.64

# %%
# 10. The top five books with the most language versions 

o = pd.read_sql_query("""

SELECT b.title, b.book_id, bl.language_name, COUNT(*) 
FROM book b
LEFT JOIN book_language bl
ON b.language_id = bl.language_id
GROUP BY b.book_id
ORDER BY COUNT(DISTINCT(bl.language_name)) DESC 
LIMIT 5;

""" , con = conn) 
o
# Out:
#                                                title  book_id  \
# 0        The World's First Love: Mary  Mother of God        1
# 1                                     The Illuminati        2
# 2                                 The Servant Leader        3
# 3  What Life Was Like in the Jewel in the Crown: ...        4
# 4  Cliffs Notes on Aristophanes' Lysistrata  The ...        5
#
#            language_name  COUNT(*)
# 0  United States English         1
# 1                English         1
# 2                English         1
# 3                English         1
# 4                English         1

# %%
# 11. Books in different languages rank

p = pd.read_sql_query("""

SELECT bl.language_id, bl.language_name, COUNT(*), COUNT(*) * 100.0 / SUM(COUNT(*)) OVER() AS 'Percent of total'
FROM book_language bl
RIGHT JOIN book b
ON bl.language_id = b.language_id
GROUP BY b.language_id
ORDER BY COUNT(*) DESC;

""" , con = conn) 
p
# Out:
#     language_id          language_name  COUNT(*)  Percent of total
# 0             1                English      8911          80.08448
# 1             2  United States English      1409          12.66289
# 2             4                Spanish       218           1.95920
# 3             5        British English       214           1.92325
# 4             3                 French       144           1.29415
# 5            10                 German        99           0.88973
# 6            11               Japanese        46           0.41341
# 7             6     Multiple Languages        19           0.17076
# 8            14                Chinese        14           0.12582
# 9             7                  Greek        11           0.09886
# 10           16             Portuguese        10           0.08987
# 11            9       Canadian English         7           0.06291
# 12           18                Italian         5           0.04494
# 13            8         Middle English         3           0.02696
# 14           15                  Latin         3           0.02696
# 15           19                Russian         2           0.01797
# 16           23                Swedish         2           0.01797
# 17           12                 Arabic         1           0.00899
# 18           13                  Dutch         1           0.00899
# 19           17                Serbian         1           0.00899
# 20           20              Malaysian         1           0.00899
# 21           21               Galician         1           0.00899
# 22           22                  Welsh         1           0.00899
# 23           24              Norwegian         1           0.00899
# 24           25                Turkish         1           0.00899
# 25           26                 Gaelic         1           0.00899
# 26           27                  Aleut         1           0.00899

# %%
# plot of count of books in each language 
plt.figure(figsize=(10,6))
plt.bar(p['language_name'], p['COUNT(*)'])
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.title('Count of Books by Language')
plt.ylabel('Count')
plt.xlabel('Language')
plt.show()

# %%
# 12. Which customer brings in the most profit?

q = pd.read_sql_query("""

SELECT c.customer_id, c.first_name, c.last_name, SUM(ol.price) AS Spent 
FROM customer c
INNER JOIN cust_order co
ON c.customer_id = co.customer_id
INNEr JOIN order_line ol
ON co.order_id = ol.order_id 
GROUP BY c.customer_id
ORDER BY Spent DESC
LIMIT 5;

""" , con = conn) 
q
# Out:
#    customer_id first_name last_name   Spent
# 0         1457    Trstram   Jellman  485.01
# 1          388    Jeramie    Leggis  414.18
# 2         1556      Emmet     Kupis  401.41
# 3         1599     Jeffry     Blasl  396.14
# 4         1830     Noella   Ruddoch  392.72

# %%
# 13. The top five cities have the most orders placed by customers. 

r = pd.read_sql_query("""

SELECT ad.city, ctr.country_name, COUNT(*), COUNT(*) * 100.0 / SUM(COUNT(*)) OVER() AS 'Percent of total'
FROM address ad
INNER JOIN customer_address ca
ON ad.address_id = ca.address_id
INNER JOIN cust_order co
ON ca.customer_id = co.customer_id
INNER JOIN order_line ol
ON co.order_id = ol.order_id
INNER JOIN country ctr
ON ad.country_id = ctr.country_id
GROUP BY ad.city, ctr.country_name
ORDER BY COUNT(*) DESC 
LIMIT 5;

""" , con = conn) 
r
# Out:
#         city              country_name  COUNT(*)  Percent of total
# 0  Holoubkov            Czech Republic       201           0.63830
# 1     Dallas  United States of America       195           0.61924
# 2      Teeli                    Russia       168           0.53350
# 3     Wińsko                    Poland       166           0.52715
# 4  Quebradas                  Honduras       162           0.51445

# %%
# plot of top 5 countries customers placed orders in 
plt.bar(r['country_name'], r['COUNT(*)'])
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.title('Count of Books sold by Country')
plt.ylabel('Count')
plt.xlabel('Country')
plt.show()

# %% [markdown]
# ## Adding External Data Sources

# %%
popdata = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_4770387_2.csv')
incomedata = pd.read_csv('Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_4770387_2.csv')

# %%
print(popdata.shape)
print(popdata.columns)
popdata
# Out:
# (265, 4)
# Index(['countrycode', 'countryname', 'population2020', 'population2021'], dtype='object')
#     countrycode                  countryname  population2020  population2021
# 0           ABW                        Aruba          106585          106537
# 1           AFE  Africa Eastern and Southern       685112705       702976832
# 2           AFG                  Afghanistan        38972230        40099462
# 3           AFW   Africa Western and Central       466189102       478185907
# 4           AGO                       Angola        33428486        34503774
# ..          ...                          ...             ...             ...
# 260         XKX                       Kosovo         1790133         1786038
# 261         YEM                  Yemen, Rep.        32284046        32981641
# 262         ZAF                 South Africa        58801927        59392255
# 263         ZMB                       Zambia        18927715        19473125
# 264         ZWE                     Zimbabwe        15669666        15993524
#
# [265 rows x 4 columns]

# %%
r = pd.read_sql_query("""
drop table population;
""" , con = conn) 

## May output error table does not exist, this is just helpful for restart.
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1051, "Unknown table 'gravity_books.population'")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 r = pd.read_sql_query("""
#       2 drop table population;
#       3 """ , con = conn)
#       5 ## May output error table does not exist, this is just helpful for restart.
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2078, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2066 def read_query(
#    2067     self,
#    2068     sql,
#    (...)
#    2074     dtype: DtypeArg | None = None,
#    2075 ) -> DataFrame | Iterator[DataFrame]:
#    2077     args = _convert_params(sql, params)
# -> 2078     cursor = self.execute(*args)
#    2079     columns = [col_desc[0] for col_desc in cursor.description]
#    2081     if chunksize is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2030, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2027     raise ex from inner_exc
#    2029 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2030 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# drop table population;
# ': (1051, "Unknown table 'gravity_books.population'")

# %%
r = pd.read_sql_query("""
create TABLE population (
	countrycode varchar(5),
	countryname varchar(100),
	population2020 bigint,
	population2021 bigint
	)
""" , con = conn) 

## Will always output error TypeError: 'NoneType' object is not iterable -- you can ignore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 r = pd.read_sql_query("""
#       2 create TABLE population (
#       3 	countrycode varchar(5),
#       4 	countryname varchar(100),
#       5 	population2020 bigint,
#       6 	population2021 bigint
#       7 	)
#       8 """ , con = conn)
#      10 ## Will always output error TypeError: 'NoneType' object is not iterable -- you can ignore
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2079, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2077 args = _convert_params(sql, params)
#    2078 cursor = self.execute(*args)
# -> 2079 columns = [col_desc[0] for col_desc in cursor.description]
#    2081 if chunksize is not None:
#    2082     return self._query_iterator(
#    2083         cursor,
#    2084         chunksize,
#    (...)
#    2089         dtype=dtype,
#    2090     )
#
# TypeError: 'NoneType' object is not iterable

# %%
cursor = conn.cursor()
for i,row in popdata.iterrows():
            sql = "INSERT INTO population VALUES (%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            conn.commit()

# %%
pd.read_sql_query("""
select * from population
""" , con = conn)
# Out:
#     countrycode                  countryname  population2020  population2021
# 0           ABW                        Aruba          106585          106537
# 1           AFE  Africa Eastern and Southern       685112705       702976832
# 2           AFG                  Afghanistan        38972230        40099462
# 3           AFW   Africa Western and Central       466189102       478185907
# 4           AGO                       Angola        33428486        34503774
# ..          ...                          ...             ...             ...
# 260         XKX                       Kosovo         1790133         1786038
# 261         YEM                  Yemen, Rep.        32284046        32981641
# 262         ZAF                 South Africa        58801927        59392255
# 263         ZMB                       Zambia        18927715        19473125
# 264         ZWE                     Zimbabwe        15669666        15993524
#
# [265 rows x 4 columns]

# %%
print(incomedata.shape)
print(incomedata.columns)
incomedata
# Out:
# (265, 4)
# Index(['countrycode', 'region', 'incomegroup', 'countryname'], dtype='object')
#     countrycode                      region          incomegroup  \
# 0           ABW   Latin America & Caribbean          High income
# 1           AFE                         NaN                  NaN
# 2           AFG                  South Asia           Low income
# 3           AFW                         NaN                  NaN
# 4           AGO          Sub-Saharan Africa  Lower middle income
# ..          ...                         ...                  ...
# 260         XKX       Europe & Central Asia  Upper middle income
# 261         YEM  Middle East & North Africa           Low income
# 262         ZAF          Sub-Saharan Africa  Upper middle income
# 263         ZMB          Sub-Saharan Africa           Low income
# 264         ZWE          Sub-Saharan Africa  Lower middle income
#
#                      countryname
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 4 columns]

# %%
incomedata = incomedata.dropna()

# %%
r = pd.read_sql_query("""
drop table income;
""" , con = conn) 

## May output error table does not exist, this is just helpful for restart.
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1051, "Unknown table 'gravity_books.income'")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 r = pd.read_sql_query("""
#       2 drop table income;
#       3 """ , con = conn)
#       5 ## May output error table does not exist, this is just helpful for restart.
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2078, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2066 def read_query(
#    2067     self,
#    2068     sql,
#    (...)
#    2074     dtype: DtypeArg | None = None,
#    2075 ) -> DataFrame | Iterator[DataFrame]:
#    2077     args = _convert_params(sql, params)
# -> 2078     cursor = self.execute(*args)
#    2079     columns = [col_desc[0] for col_desc in cursor.description]
#    2081     if chunksize is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2030, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2027     raise ex from inner_exc
#    2029 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2030 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# drop table income;
# ': (1051, "Unknown table 'gravity_books.income'")

# %%
r = pd.read_sql_query("""
create TABLE income (
	countrycode varchar(5),
	region varchar(255),
	incomegroup varchar(255),
	countryname varchar(100)
)
""" , con = conn) 

## Will always output error TypeError: 'NoneType' object is not iterable -- you can ignore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 r = pd.read_sql_query("""
#       2 create TABLE income (
#       3 	countrycode varchar(5),
#       4 	region varchar(255),
#       5 	incomegroup varchar(255),
#       6 	countryname varchar(100)
#       7 )
#       8 """ , con = conn)
#      10 ## Will always output error TypeError: 'NoneType' object is not iterable -- you can ignore
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2079, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2077 args = _convert_params(sql, params)
#    2078 cursor = self.execute(*args)
# -> 2079 columns = [col_desc[0] for col_desc in cursor.description]
#    2081 if chunksize is not None:
#    2082     return self._query_iterator(
#    2083         cursor,
#    2084         chunksize,
#    (...)
#    2089         dtype=dtype,
#    2090     )
#
# TypeError: 'NoneType' object is not iterable

# %%
cursor = conn.cursor()
for i,row in incomedata.iterrows():
            sql = "INSERT INTO income VALUES (%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            conn.commit()

# %%
s = pd.read_sql_query("""
select * from income
""" , con = conn)

s
# Out:
#     countrycode                      region          incomegroup   countryname
# 0           ABW   Latin America & Caribbean          High income         Aruba
# 1           AFG                  South Asia           Low income   Afghanistan
# 2           AGO          Sub-Saharan Africa  Lower middle income        Angola
# 3           ALB       Europe & Central Asia  Upper middle income       Albania
# 4           AND       Europe & Central Asia          High income       Andorra
# ..          ...                         ...                  ...           ...
# 211         XKX       Europe & Central Asia  Upper middle income        Kosovo
# 212         YEM  Middle East & North Africa           Low income   Yemen, Rep.
# 213         ZAF          Sub-Saharan Africa  Upper middle income  South Africa
# 214         ZMB          Sub-Saharan Africa           Low income        Zambia
# 215         ZWE          Sub-Saharan Africa  Lower middle income      Zimbabwe
#
# [216 rows x 4 columns]

# %%
# income plot 
values = ['Low Income', 'Lower Middle Income', 'Upper Middle Income', 'High Income']

plt.ba)

# %%
pd.read_sql_query("""
select * from country
""" , con = conn)
# Out:
#      country_id          country_name
# 0             1           Afghanistan
# 1             2  Netherlands Antilles
# 2             3               Albania
# 3             4               Algeria
# 4             5               Andorra
# ..          ...                   ...
# 227         228            Yugoslavia
# 228         229                Zambia
# 229         230              Zimbabwe
# 230         231             Singapore
# 231         232      French Polynesia
#
# [232 rows x 2 columns]

# %%
pd.read_sql_query("""
select * from country c
join income i on i.countryname = c.country_name
""" , con = conn)

## There are only matches on 175 rows
# Out:
#      country_id      country_name countrycode                      region  \
# 0             1       Afghanistan         AFG                  South Asia
# 1             3           Albania         ALB       Europe & Central Asia
# 2             4           Algeria         DZA  Middle East & North Africa
# 3             5           Andorra         AND       Europe & Central Asia
# 4             6            Angola         AGO          Sub-Saharan Africa
# ..          ...               ...         ...                         ...
# 170         221           Vietnam         VNM         East Asia & Pacific
# 171         229            Zambia         ZMB          Sub-Saharan Africa
# 172         230          Zimbabwe         ZWE          Sub-Saharan Africa
# 173         231         Singapore         SGP         East Asia & Pacific
# 174         232  French Polynesia         PYF         East Asia & Pacific
#
#              incomegroup       countryname
# 0             Low income       Afghanistan
# 1    Upper middle income           Albania
# 2    Lower middle income           Algeria
# 3            High income           Andorra
# 4    Lower middle income            Angola
# ..                   ...               ...
# 170  Lower middle income           Vietnam
# 171           Low income            Zambia
# 172  Lower middle income          Zimbabwe
# 173          High income         Singapore
# 174          High income  French Polynesia
#
# [175 rows x 6 columns]

# %%
pd.read_sql_query("""
select * from country c
join population p on p.countryname = c.country_name
""" , con = conn)

## There are only matches on 175 rows
# Out:
#      country_id  country_name countrycode   countryname  population2020  \
# 0            11         Aruba         ABW         Aruba          106585
# 1             1   Afghanistan         AFG   Afghanistan        38972230
# 2             6        Angola         AGO        Angola        33428486
# 3             3       Albania         ALB       Albania         2837849
# 4             5       Andorra         AND       Andorra           77700
# ..          ...           ...         ...           ...             ...
# 170         175         Samoa         WSM         Samoa          214929
# 171         111        Kosovo         XKX        Kosovo         1790133
# 172         171  South Africa         ZAF  South Africa        58801927
# 173         229        Zambia         ZMB        Zambia        18927715
# 174         230      Zimbabwe         ZWE      Zimbabwe        15669666
#
#      population2021
# 0            106537
# 1          40099462
# 2          34503774
# 3           2811666
# 4             79034
# ..              ...
# 170          218764
# 171         1786038
# 172        59392255
# 173        19473125
# 174        15993524
#
# [175 rows x 6 columns]

# %%
# amount spent by country
t = pd.read_sql_query("""
select distinct
    i.incomegroup, 
    pop.population2020, 
    pop.population2021,
    c.country_name as country,
    sum(ol.price) over (partition by c.country_name, i.incomegroup) as 'Total amount spent by country and income group'
from cust_order co
join order_line ol on ol.order_id = co.order_id
join customer_address ca on ca.customer_id = co.customer_id
join address a on a.address_id = ca.address_id
join country c on c.country_id = a.country_id
join income i on i.countryname = c.country_name
join population pop on pop.countryname = i.countryname
ORDER BY 5 DESC
;
""" , con = conn)

t
# Out:
#             incomegroup  population2020  population2021      country  \
# 0   Upper middle income      1411100000      1412360000        China
# 1   Lower middle income       271857970       273753191    Indonesia
# 2           High income        37899070        37747124       Poland
# 3   Lower middle income       112190977       113880328  Philippines
# 4           High income        10297081        10325147     Portugal
# ..                  ...             ...             ...          ...
# 86          High income         9215100         9364000       Israel
# 87           Low income        44404611        45853778       Uganda
# 88           Low income       117190911       120283026     Ethiopia
# 89  Upper middle income        18755666        19000988   Kazakhstan
# 90  Upper middle income          621306          619211   Montenegro
#
#     Total amount spent by country and income group
# 0                                         52528.83
# 1                                         41001.72
# 2                                         13489.46
# 3                                         13351.89
# 4                                         12309.05
# ..                                             ...
# 86                                           91.84
# 87                                           56.85
# 88                                           43.34
# 89                                           16.85
# 90                                           14.19
#
# [91 rows x 5 columns]

# %%
# bar chart of amoutn spent by country 
plt.figure(figsize=(10,7))
plt.bar(t['country'], t['Total amount spent by country and income group'])
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.title('Amount Spent on Books by Country')
plt.ylabel('Amount Spent in Dollars')
plt.xlabel('Country')
plt.show()

# Note: interesting that while china spends the most in dollars on books, they aren't the first in number of orders, meaning that on average chinese customers are buying more expensive books. 
# This is likely related to incomegroup.
